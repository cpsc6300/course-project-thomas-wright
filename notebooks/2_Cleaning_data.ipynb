# %% [markdown]
# # Cleaning data for models and visualization

# %% [markdown]
# First steps in cleaning data are to make all the values that can be entirly numeric

# %% [markdown]
# Before we do that we must import our utility scripts

# %%
import sys
import os
import pandas as pd
import numpy as  np

project_dir = '/home/atoris/course-project-thomas-wright/src'
if project_dir not in sys.path:
    sys.path.insert(0, project_dir)

# %%
import datautil as du

# %% [markdown]
# But first we must be able to load our data

# %%
url = 'https://www.cpubenchmark.net/mid_range_cpus.html'
filename = 'cpu_data.csv'

df = du.load_data(url, filename)
df.head(5)
# Out:
# /usr/home/atoris/course-project-thomas-wright/data/cpu_data.csv
#                                 name      price    Class  Socket  Clockspeed  \
# 0  AMD Ryzen Threadripper PRO 3995WX        NaN  Desktop  sTRX4          2.7
# 1       AMD Ryzen Threadripper 3990X  $4,999.99  Desktop  sTRX4          2.9
# 2                      AMD EPYC 7702  $4,955.00   Server    SP3          2.0
# 3                     AMD EPYC 7702P  $4,749.95   Server    SP3          2.0
# 4                      AMD EPYC 7742  $6,790.00   Server    SP3          2.3
#
#    Turbo Speed  Threads  Cores Typical TDP  mt_score  st_score
# 0          4.2      128     64        280W     88731      2665
# 1          4.3      128     64        280W     80558      2556
# 2          3.4      128     64        200W     71859      2096
# 3          3.4      128     64        200W     68213      2210
# 4          3.4      128     64        225W     67185      2376

# %% [markdown]
# It looks like we could remove the units from price and TDP and encode our Class with a OneHot encode,
# I will start with the units

# %%
for index, value in df.iterrows():
    price = str(value['price']).replace("*", "")
    TDP = str(value['Typical TDP'])
    
    if price[0] == "$":
        price = price[1:]
        price = price.replace(",", "")
    if TDP[-1:] == "W":
        TDP = TDP[:-1]
    if ((TDP[-1:] == "3") or (TDP[-1:] == "2")):
        if(TDP[-2:-1] == "W"):
            TDP = TDP[:-2]
        
    
    
    df.at[index, 'price'] = price
    df.at[index, 'Typical TDP'] = TDP

# %%
df.head(1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 740 entries, 0 to 739
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         740 non-null    object
#  1   price        740 non-null    object
#  2   Class        712 non-null    object
#  3   Socket       706 non-null    object
#  4   Clockspeed   740 non-null    float64
#  5   Turbo Speed  436 non-null    float64
#  6   Threads      740 non-null    int64
#  7   Cores        740 non-null    int64
#  8   Typical TDP  740 non-null    object
#  9   mt_score     740 non-null    int64
#  10  st_score     740 non-null    int64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 63.7+ KB

# %% [markdown]
# In this dataset singlethreaded_score should always be less than mulithreaded_score so we should verify that this is correct. Some errors happen during data collection process that could make this false so we should fix them by dropping the row or getting the correct value.

# %%
for index, value in df.iterrows():
    st_score = value['st_score']
    mt_score = value['mt_score']
    
    if st_score > mt_score:
        st_score = str(st_score)[:-1]
    
    df.at[index, 'st_score'] = int(st_score)
df.head(1)
# Out:
#                                 name price    Class  Socket  Clockspeed  \
# 0  AMD Ryzen Threadripper PRO 3995WX   nan  Desktop  sTRX4          2.7
#
#    Turbo Speed  Threads  Cores Typical TDP  mt_score  st_score
# 0          4.2      128     64         280     88731      2665

# %% [markdown]
# This data looks good except the names not look a bit messy and contain redudant data so we will split the data up into Brand and name and remove the clock speed as it's data already has a column

# %%
for index, value in df.iterrows():
    name = str(value['name'])
    
    if name[0] == 'I':
        df.at[index, 'brand'] = 'Intel'
        name = name[6:]
    if name[0] == "A":
        df.at[index, 'brand'] = "Amd"
        name = name[4:]
        
    name = name.split("@")
    df.at[index, 'name'] = name[0]
    
df.head(5)
# Out:
#                             name    price    Class  Socket  Clockspeed  \
# 0  Ryzen Threadripper PRO 3995WX      nan  Desktop  sTRX4          2.7
# 1       Ryzen Threadripper 3990X  4999.99  Desktop  sTRX4          2.9
# 2                      EPYC 7702  4955.00   Server    SP3          2.0
# 3                     EPYC 7702P  4749.95   Server    SP3          2.0
# 4                      EPYC 7742  6790.00   Server    SP3          2.3
#
#    Turbo Speed  Threads  Cores Typical TDP  mt_score  st_score brand
# 0          4.2      128     64         280     88731      2665   Amd
# 1          4.3      128     64         280     80558      2556   Amd
# 2          3.4      128     64         200     71859      2096   Amd
# 3          3.4      128     64         200     68213      2210   Amd
# 4          3.4      128     64         225     67185      2376   Amd

# %% [markdown]
# The data looks mostly fine now but we have to do something about our missing values again dropping or replacing them, for Turbo speed we can just input the base clock speed. For price we may have to drop the row entirly or fine the price somewhere else as using the mean of the dataset can make unappropriate assumptions about cpu's.

# %%
for index, value in df.iterrows():
    clock = value['Clockspeed']
    
    if value['Turbo Speed'] == np.nan:
        df.at[index, 'Turbo Speed'] = clock
    
df.head(5)
# Out:
#                             name    price    Class  Socket  Clockspeed  \
# 0  Ryzen Threadripper PRO 3995WX      nan  Desktop  sTRX4          2.7
# 1       Ryzen Threadripper 3990X  4999.99  Desktop  sTRX4          2.9
# 2                      EPYC 7702  4955.00   Server    SP3          2.0
# 3                     EPYC 7702P  4749.95   Server    SP3          2.0
# 4                      EPYC 7742  6790.00   Server    SP3          2.3
#
#    Turbo Speed  Threads  Cores Typical TDP  mt_score  st_score brand
# 0          4.2      128     64         280     88731      2665   Amd
# 1          4.3      128     64         280     80558      2556   Amd
# 2          3.4      128     64         200     71859      2096   Amd
# 3          3.4      128     64         200     68213      2210   Amd
# 4          3.4      128     64         225     67185      2376   Amd

# %% [markdown]
# Now that our data looks good we need to make sure they are all the correct data type

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 740 entries, 0 to 739
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         740 non-null    object
#  1   price        740 non-null    object
#  2   Class        712 non-null    object
#  3   Socket       706 non-null    object
#  4   Clockspeed   740 non-null    float64
#  5   Turbo Speed  436 non-null    float64
#  6   Threads      740 non-null    int64
#  7   Cores        740 non-null    int64
#  8   Typical TDP  740 non-null    object
#  9   mt_score     740 non-null    int64
#  10  st_score     740 non-null    int64
#  11  brand        736 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 69.5+ KB

# %%
cols = ['price']
df[cols] = df[cols].apply(pd.to_numeric, downcast='float', errors='coerce')
df.head(10)
# Out:
#                             name        price    Class  Socket  Clockspeed  \
# 0  Ryzen Threadripper PRO 3995WX          NaN  Desktop  sTRX4          2.7
# 1       Ryzen Threadripper 3990X  4999.990234  Desktop  sTRX4          2.9
# 2                      EPYC 7702  4955.000000   Server    SP3          2.0
# 3                     EPYC 7702P  4749.950195   Server    SP3          2.0
# 4                      EPYC 7742  6790.000000   Server    SP3          2.3
# 5       Ryzen Threadripper 3970X  2061.830078  Desktop  sTRX4          3.7
# 6  Ryzen Threadripper PRO 3975WX          NaN  Desktop  sTRX4          3.5
# 7       Ryzen Threadripper 3960X  1349.989990  Desktop  sTRX4          3.8
# 8                      EPYC 7502  2285.000000   Server    SP3          2.5
# 9                  Ryzen 9 5950X  1679.989990  Desktop    AM4          3.4
#
#    Turbo Speed  Threads  Cores Typical TDP  mt_score  st_score brand
# 0          4.2      128     64         280     88731      2665   Amd
# 1          4.3      128     64         280     80558      2556   Amd
# 2          3.4      128     64         200     71859      2096   Amd
# 3          3.4      128     64         200     68213      2210   Amd
# 4          3.4      128     64         225     67185      2376   Amd
# 5          4.5       64     32         280     64253      2713   Amd
# 6          4.2       64     32         280     63616      2668   Amd
# 7          4.5       48     24         280     55459      2703   Amd
# 8          3.4       64     32         180     53591      2116   Amd
# 9          4.9       32     16         105     46244      3529   Amd

# %% [markdown]
# Last thing to do is get rid of all the Null or NaN values

# %%
df['Turbo Speed'].fillna(df['Clockspeed'], inplace=True)
df.info()
df.dropna(subset=['Class', 'brand'], inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 740 entries, 0 to 739
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         740 non-null    object
#  1   price        497 non-null    float32
#  2   Class        712 non-null    object
#  3   Socket       706 non-null    object
#  4   Clockspeed   740 non-null    float64
#  5   Turbo Speed  740 non-null    float64
#  6   Threads      740 non-null    int64
#  7   Cores        740 non-null    int64
#  8   Typical TDP  740 non-null    object
#  9   mt_score     740 non-null    int64
#  10  st_score     740 non-null    int64
#  11  brand        736 non-null    object
# dtypes: float32(1), float64(2), int64(4), object(5)
# memory usage: 66.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 708 entries, 0 to 739
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         708 non-null    object
#  1   price        486 non-null    float32
#  2   Class        708 non-null    object
#  3   Socket       691 non-null    object
#  4   Clockspeed   708 non-null    float64
#  5   Turbo Speed  708 non-null    float64
#  6   Threads      708 non-null    int64
#  7   Cores        708 non-null    int64
#  8   Typical TDP  708 non-null    object
#  9   mt_score     708 non-null    int64
#  10  st_score     708 non-null    int64
#  11  brand        708 non-null    object
# dtypes: float32(1), float64(2), int64(4), object(5)
# memory usage: 69.1+ KB

# %% [markdown]
# Now that the data has been cleaned we can save it.

# %%
du.save_df(df, 'cpu_data_cleaned.csv')

# %% [markdown]
# Now we can implement pandas OneHotEncode on our class and brand

# %%
pd.get_dummies(df['Class'], prefix='class')
df = pd.concat([df,pd.get_dummies(df['Class'], prefix='class')], axis=1)
df = pd.concat([df,pd.get_dummies(df['brand'], prefix='brand')], axis=1)

# %%
df.head(60)
# Out:
#                              name        price    Class      Socket  \
# 0   Ryzen Threadripper PRO 3995WX          NaN  Desktop      sTRX4
# 1        Ryzen Threadripper 3990X  4999.990234  Desktop      sTRX4
# 2                       EPYC 7702  4955.000000   Server        SP3
# 3                      EPYC 7702P  4749.950195   Server        SP3
# 4                       EPYC 7742  6790.000000   Server        SP3
# 5        Ryzen Threadripper 3970X  2061.830078  Desktop      sTRX4
# 6   Ryzen Threadripper PRO 3975WX          NaN  Desktop      sTRX4
# 7        Ryzen Threadripper 3960X  1349.989990  Desktop      sTRX4
# 8                       EPYC 7502  2285.000000   Server        SP3
# 9                   Ryzen 9 5950X  1679.989990  Desktop        AM4
# 10                     EPYC 7502P  2697.179932   Server        SP3
# 11                      EPYC 7452  2288.989990   Server        SP3
# 12  Ryzen Threadripper PRO 3955WX          NaN  Desktop      sTRX4
# 13                  Ryzen 9 5900X  1099.989990  Desktop        AM4
# 14                  Xeon W-3275M   7453.000000   Server  FCLGA3647
# 15                  Ryzen 9 3950X   721.989990  Desktop        AM4
# 16                     EPYC 7402P  1435.989990   Server        SP3
# 17               Xeon Gold 6248R   2826.310059   Server  FCLGA3647
# 18            Xeon Platinum 8280   9949.000000   Server  FCLGA3647
# 19               Xeon Gold 6242R   2641.870117   Server  FCLGA3647
# 20  Ryzen Threadripper PRO 3945WX          NaN  Desktop      sTRX4
# 21               Core i9-10980XE    999.989990  Desktop  FCLGA2066
# 22                      EPYC 7302  1192.920044   Server        SP3
# 23                 Ryzen 9 3900XT   629.250000  Desktop        AM4
# 24            Xeon Platinum 8168   5890.000000   Server  FCLGA3647
# 25                  Ryzen 9 3900X   605.669983  Desktop        AM4
# 27  Intel              0             0             1          0            1
# 28  Intel              1             0             0          0            1
# 29  Intel              1             0             0          0            1
# 30  Intel              1             0             0          0            1
# 31    Amd              1             0             0          1            0
# 32    Amd              1             0             0          1            0
# 33  Intel              0             0             1          0            1
# 34  Intel              1             0             0          0            1
# 35    Amd              1             0             0          1            0
# 36  Intel              0             0             1          0            1
# 37  Intel              0             0             1          0            1
# 38  Intel              0             0             1          0            1
# 39    Amd              1             0             0          1            0
# 40  Intel              0             0             1          0            1
# 41  Intel              0             0             1          0            1
# 42  Intel              1             0             0          0            1
# 43  Intel              1             0             0          0            1
# 44  Intel              0             0             1          0            1
# 45    Amd              1             0             0          1            0
# 46    Amd              0             0             1          1            0
# 47  Intel              1             0             0          0            1
# 48    Amd              1             0             0          1            0
# 49  Intel              0             0             1          0            1
# 50  Intel              0             0             1          0            1
# 51    Amd              0             0             1          1            0
# 52  Intel              0             0             1          0            1
# 53  Intel              0             0             1          0            1
# 54  Intel              1             0             0          0            1
# 55  Intel              1             0             0          0            1
# 56  Intel              0             0             1          0            1
# 57  Intel              0             0             1          0            1
# 58    Amd              1             0             0          1            0
# 59  Intel              0             0             1          0            1

# %% [markdown]
# Now that our class has been OneHot encoded we can drop our old collumns

# %%
df.drop(['Class'],axis=1,inplace=True)
df.drop(['brand'],axis=1,inplace=True)
df.head()
# Out:
#                             name        price  Socket  Clockspeed  \
# 0  Ryzen Threadripper PRO 3995WX          NaN  sTRX4          2.7
# 1       Ryzen Threadripper 3990X  4999.990234  sTRX4          2.9
# 2                      EPYC 7702  4955.000000    SP3          2.0
# 3                     EPYC 7702P  4749.950195    SP3          2.0
# 4                      EPYC 7742  6790.000000    SP3          2.3
#
#    Turbo Speed  Threads  Cores Typical TDP  mt_score  st_score  class_Desktop  \
# 0          4.2      128     64         280     88731      2665              1
# 1          4.3      128     64         280     80558      2556              1
# 2          3.4      128     64         200     71859      2096              0
# 3          3.4      128     64         200     68213      2210              0
# 4          3.4      128     64         225     67185      2376              0
#
#    class_Laptop  class_Server  brand_Amd  brand_Intel
# 0             0             0          1            0
# 1             0             0          1            0
# 2             0             1          1            0
# 3             0             1          1            0
# 4             0             1          1            0

# %% [markdown]
# Saving the encoded data

# %%
du.save_df(df, 'cpu_data_encoded.csv')

# %% [markdown]
# Verify project structure

# %%
# !tree ../
# Out:
# ../
# ├── LICENSE
# ├── README.md
# ├── data
# │   ├── Feature_importance.png
# │   ├── cpu_data.csv
# │   ├── cpu_data_cleaned.csv
# │   └── cpu_data_encoded.csv
# ├── models
# ├── notebooks
# │   ├── 0_setup_project_folders.ipynb
# │   ├── 1_Retrieving_data.ipynb
# │   ├── 2_Cleaning_data.ipynb
# │   ├── 3_Simple_Graphs.ipynb
# │   └── __pycache__
# │       └── datautil.cpython-37.pyc
# ├── report
# │   ├── interim.md
# │   ├── proposal.md
# │   └── report.md
# ├── src
# │   ├── __pycache__
# │   │   └── datautil.cpython-37.pyc
# │   └── datautil.py
# └── web
#     └── atoris
#
# 9 directories, 16 files
