# %% [markdown]
# # Cleaning data for models and visualization

# %% [markdown]
# First steps in cleaning data are to make all the values that can be entirly numeric

# %% [markdown]
# Before we do that we must import our utility scripts

# %%
import sys
import os
import pandas as pd
import numpy as  np

project_dir = '/home/atoris/course-project-thomas-wright/src'
if project_dir not in sys.path:
    sys.path.insert(0, project_dir)

# %%
import datautil as du

# %% [markdown]
# But first we must be able to load our data

# %%
url = 'https://www.cpubenchmark.net/mid_range_cpus.html'
filename = 'cpu_data.csv'

df = du.load_data(url, filename)
df.head(5)
# Out:
# /usr/home/atoris/course-project-thomas-wright/data/cpu_data.csv
#                                 name      price    Class  Socket  Clockspeed  \
# 0  AMD Ryzen Threadripper PRO 3995WX        NaN  Desktop  sTRX4          2.7
# 1       AMD Ryzen Threadripper 3990X  $3,849.99  Desktop  sTRX4          2.9
# 2                      AMD EPYC 7702  $6,229.00   Server    SP3          2.0
# 3                     AMD EPYC 7702P  $4,088.00   Server    SP3          2.0
# 4                      AMD EPYC 7742  $7,549.35   Server    SP3          2.3
#
#    Turbo Speed  Threads  Cores Typical TDP  mt_score  st_score
# 0          4.2      128     64        280W     88673      2676
# 1          4.3      128     64        280W     80508      2545
# 2          3.4      128     64        200W     71859      2096
# 3          3.4      128     64        200W     68213      2210
# 4          3.4      128     64        225W     67185      2376

# %% [markdown]
# It looks like we could remove the units from price and TDP and encode our Class with a OneHot encode,
# I will start with the units

# %%
for index, value in df.iterrows():
    price = str(value['price']).replace("*", "")
    TDP = str(value['Typical TDP'])
    
    if price[0] == "$":
        price = price[1:]
        price = price.replace(",", "")
    if TDP[-1:] == "W":
        TDP = TDP[:-1]
    if ((TDP[-1:] == "3") or (TDP[-1:] == "2")):
        if(TDP[-2:-1] == "W"):
            TDP = TDP[:-2]
        
    
    
    df.at[index, 'price'] = price
    df.at[index, 'Typical TDP'] = TDP

# %%
df.head(1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         500 non-null    object
#  1   price        500 non-null    object
#  2   Class        482 non-null    object
#  3   Socket       478 non-null    object
#  4   Clockspeed   500 non-null    float64
#  5   Turbo Speed  300 non-null    float64
#  6   Threads      500 non-null    int64
#  7   Cores        500 non-null    int64
#  8   Typical TDP  500 non-null    object
#  9   mt_score     500 non-null    int64
#  10  st_score     500 non-null    int64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 43.1+ KB

# %% [markdown]
# In this dataset singlethreaded_score should always be less than mulithreaded_score so we should verify that this is correct. Some errors happen during data collection process that could make this false so we should fix them by dropping the row or getting the correct value.

# %%
for index, value in df.iterrows():
    st_score = value['st_score']
    mt_score = value['mt_score']
    
    if st_score > mt_score:
        st_score = str(st_score)[:-1]
    
    df.at[index, 'st_score'] = int(st_score)
df.head(1)
# Out:
#                                 name price    Class  Socket  Clockspeed  \
# 0  AMD Ryzen Threadripper PRO 3995WX   nan  Desktop  sTRX4          2.7
#
#    Turbo Speed  Threads  Cores Typical TDP  mt_score  st_score
# 0          4.2      128     64         280     88673      2676

# %% [markdown]
# This data looks good except the names not look a bit messy and contain redudant data so we will split the data up into Brand and name and remove the clock speed as it's data already has a column

# %%
for index, value in df.iterrows():
    name = str(value['name'])
    
    if name[0] == 'I':
        df.at[index, 'brand'] = 'Intel'
        name = name[6:]
    if name[0] == "A":
        df.at[index, 'brand'] = "Amd"
        name = name[4:]
        
    name = name.split("@")
    df.at[index, 'name'] = name[0]
    
df.head(5)
# Out:
#                             name    price    Class  Socket  Clockspeed  \
# 0  Ryzen Threadripper PRO 3995WX      nan  Desktop  sTRX4          2.7
# 1       Ryzen Threadripper 3990X  3849.99  Desktop  sTRX4          2.9
# 2                      EPYC 7702  6229.00   Server    SP3          2.0
# 3                     EPYC 7702P  4088.00   Server    SP3          2.0
# 4                      EPYC 7742  7549.35   Server    SP3          2.3
#
#    Turbo Speed  Threads  Cores Typical TDP  mt_score  st_score brand
# 0          4.2      128     64         280     88673      2676   Amd
# 1          4.3      128     64         280     80508      2545   Amd
# 2          3.4      128     64         200     71859      2096   Amd
# 3          3.4      128     64         200     68213      2210   Amd
# 4          3.4      128     64         225     67185      2376   Amd

# %% [markdown]
# The data looks mostly fine now but we have to do something about our missing values again dropping or replacing them, for Turbo speed we can just input the base clock speed. For price we may have to drop the row entirly or fine the price somewhere else as using the mean of the dataset can make unappropriate assumptions about cpu's.

# %%
for index, value in df.iterrows():
    clock = value['Clockspeed']
    
    if value['Turbo Speed'] == np.nan:
        df.at[index, 'Turbo Speed'] = clock
    
df.head(5)
# Out:
#                             name    price    Class  Socket  Clockspeed  \
# 0  Ryzen Threadripper PRO 3995WX      nan  Desktop  sTRX4          2.7
# 1       Ryzen Threadripper 3990X  3849.99  Desktop  sTRX4          2.9
# 2                      EPYC 7702  6229.00   Server    SP3          2.0
# 3                     EPYC 7702P  4088.00   Server    SP3          2.0
# 4                      EPYC 7742  7549.35   Server    SP3          2.3
#
#    Turbo Speed  Threads  Cores Typical TDP  mt_score  st_score brand
# 0          4.2      128     64         280     88673      2676   Amd
# 1          4.3      128     64         280     80508      2545   Amd
# 2          3.4      128     64         200     71859      2096   Amd
# 3          3.4      128     64         200     68213      2210   Amd
# 4          3.4      128     64         225     67185      2376   Amd

# %% [markdown]
# Now that our data looks good we need to make sure they are all the correct data type

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         500 non-null    object
#  1   price        500 non-null    object
#  2   Class        482 non-null    object
#  3   Socket       478 non-null    object
#  4   Clockspeed   500 non-null    float64
#  5   Turbo Speed  300 non-null    float64
#  6   Threads      500 non-null    int64
#  7   Cores        500 non-null    int64
#  8   Typical TDP  500 non-null    object
#  9   mt_score     500 non-null    int64
#  10  st_score     500 non-null    int64
#  11  brand        497 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 47.0+ KB

# %%
cols = ['price']
df[cols] = df[cols].apply(pd.to_numeric, downcast='float', errors='coerce')
df.head(10)
# Out:
#                             name        price    Class  Socket  Clockspeed  \
# 0  Ryzen Threadripper PRO 3995WX          NaN  Desktop  sTRX4          2.7
# 1       Ryzen Threadripper 3990X  3849.989990  Desktop  sTRX4          2.9
# 2                      EPYC 7702  6229.000000   Server    SP3          2.0
# 3                     EPYC 7702P  4088.000000   Server    SP3          2.0
# 4                      EPYC 7742  7549.350098   Server    SP3          2.3
# 5  Ryzen Threadripper PRO 3975WX          NaN  Desktop  sTRX4          3.5
# 6       Ryzen Threadripper 3970X  1999.000000  Desktop  sTRX4          3.7
# 7       Ryzen Threadripper 3960X  1349.989990  Desktop  sTRX4          3.8
# 8                  Ryzen 9 5950X   799.000000  Desktop    AM4          3.4
# 9                     EPYC 7502P  2757.959961   Server    SP3          2.5
#
#    Turbo Speed  Threads  Cores Typical TDP  mt_score  st_score brand
# 0          4.2      128     64         280     88673      2676   Amd
# 1          4.3      128     64         280     80508      2545   Amd
# 2          3.4      128     64         200     71859      2096   Amd
# 3          3.4      128     64         200     68213      2210   Amd
# 4          3.4      128     64         225     67185      2376   Amd
# 5          4.2       64     32         280     65123      2606   Amd
# 6          4.5       64     32         280     64258      2712   Amd
# 7          4.5       48     24         280     55466      2703   Amd
# 8          4.9       32     16         105     46567      3578   Amd
# 9          3.4       64     32         180     46180      1777   Amd

# %% [markdown]
# Now that the data has been cleaned we can save it.

# %%
du.save_df(df, 'cpu_data_cleaned.csv')

# %% [markdown]
# Now we can implement pandas OneHotEncode on our class and brand

# %%
pd.get_dummies(df['Class'], prefix='class')
df = pd.concat([df,pd.get_dummies(df['Class'], prefix='class')], axis=1)
df = pd.concat([df,pd.get_dummies(df['brand'], prefix='brand')], axis=1)

# %%
df.head(60)
# Out:
#                              name        price    Class      Socket  \
# 0   Ryzen Threadripper PRO 3995WX          NaN  Desktop      sTRX4
# 1        Ryzen Threadripper 3990X  3849.989990  Desktop      sTRX4
# 2                       EPYC 7702  6229.000000   Server        SP3
# 3                      EPYC 7702P  4088.000000   Server        SP3
# 4                       EPYC 7742  7549.350098   Server        SP3
# 5   Ryzen Threadripper PRO 3975WX          NaN  Desktop      sTRX4
# 6        Ryzen Threadripper 3970X  1999.000000  Desktop      sTRX4
# 7        Ryzen Threadripper 3960X  1349.989990  Desktop      sTRX4
# 8                   Ryzen 9 5950X   799.000000  Desktop        AM4
# 9                      EPYC 7502P  2757.959961   Server        SP3
# 10                      EPYC 7452  2437.179932   Server        SP3
# 11  Ryzen Threadripper PRO 3955WX          NaN  Desktop      sTRX4
# 12                  Ryzen 9 5900X   549.989990  Desktop        AM4
# 13                  Ryzen 9 3950X   709.989990  Desktop        AM4
# 14                     EPYC 7402P  1359.800049   Server        SP3
# 15               Xeon Gold 6248R   2836.550049   Server  FCLGA3647
# 16            Xeon Platinum 8280   9949.000000   Server  FCLGA3647
# 17                  Xeon W-3275M   7453.000000   Server  FCLGA3647
# 18               Xeon Gold 6242R   2753.030029   Server  FCLGA3647
# 19  Ryzen Threadripper PRO 3945WX          NaN  Desktop      sTRX4
# 20               Core i9-10980XE    817.500000  Desktop  FCLGA2066
# 21            Xeon Platinum 8168   5890.000000   Server  FCLGA3647
# 22                 Ryzen 9 3900XT   454.989990  Desktop        AM4
# 23                  Ryzen 9 3900X   439.989990  Desktop        AM4
# 24                     EPYC 7302P  1128.520020   Server        SP3
# 25                   Xeon W-2295   1333.000000   Server  FCLGA2066
# 26      Ryzen Threadripper 2990WX  1799.000000  Desktop       sTR4
# 27                Core i9-9990XE           NaN  Desktop    LGA2066
# 28                Core i9-9980XE   1049.000000  Desktop  FCLGA2066
# 29                  Xeon W-3175X   3062.500000  Desktop  FCLGA3647
# 30               Ryzen 9 PRO 3900          NaN  Desktop        AM4
# 31                Xeon Gold 6248   3304.989990   Server  FCLGA3647
# 32                 Core i9-9960X    859.070007  Desktop  FCLGA2066
# 33                   Ryzen 9 3900          NaN  Desktop        AM4
# 34               Xeon Gold 6246R   3497.469971   Server  FCLGA3647
# 35                   Xeon W-3245   2282.479980   Server  FCLGA3647
# 36          Xeon Platinum 8259CL           NaN   Server   LGA 3647
# 37       Ryzen Threadripper 2950X   589.989990  Desktop       sTR4
# 38                   Xeon W-3265   4551.370117   Server  FCLGA3647
# 39            Xeon Platinum 8268   6005.979980   Server  FCLGA3647
# 40                Core i9-7980XE   2345.330078  Desktop  FCLGA2066
# 41                Core i9-10940X    829.989990  Desktop  FCLGA2066
# 42                Xeon Gold 6254   3619.949951   Server  FCLGA3647
# 43                  Ryzen 7 5800X   449.989990  Desktop        AM4
# 44                      EPYC 7371  1808.989990   Server        SP3
# 45                 Core i9-9940X    759.960022  Desktop  FCLGA2066
# 46      Ryzen Threadripper 2970WX  1037.849976  Desktop       sTR4
# 47                Xeon Gold 6238   2612.000000   Server  FCLGA3647
# 48               Xeon Gold 6212U   2000.000000   Server  FCLGA3647
# 49                      EPYC 7571          NaN   Server        SP3
# 50           Xeon Platinum 8173M           NaN   Server  FCLGA3647
# 51               Xeon Gold 6210U   2059.860107   Server  FCLGA3647
# 52                 Core i9-7960X   1600.000000  Desktop  FCLGA2066
# 53                 Core i9-7940X   1489.949951  Desktop  FCLGA2066
# 54               Xeon Gold 6208U    989.000000   Server  FCLGA3647
# 55           Xeon Platinum 8175M           NaN   Server  FCLGA3647
# 56       Ryzen Threadripper 1950X   800.900024  Desktop       sTR4
# 57                      EPYC 7272   684.859985   Server        SP3
# 58                     EPYC 7401P   980.000000   Server        SP3
# 59                Core i9-10920X    699.989990  Desktop  FCLGA2066
#
#     Clockspeed  Turbo Speed  Threads  Cores Typical TDP  mt_score  st_
# 12    Amd              1             0             0          1            0
# 13    Amd              1             0             0          1            0
# 14    Amd              0             0             1          1            0
# 15  Intel              0             0             1          0            1
# 16  Intel              0             0             1          0            1
# 17  Intel              0             0             1          0            1
# 18  Intel              0             0             1          0            1
# 19    Amd              1             0             0          1            0
# 20  Intel              1             0             0          0            1
# 21  Intel              0             0             1          0            1
# 22    Amd              1             0             0          1            0
# 23    Amd              1             0             0          1            0
# 24    Amd              0             0             1          1            0
# 25  Intel              0             0             1          0            1
# 26    Amd              1             0             0          1            0
# 27  Intel              1             0             0          0            1
# 28  Intel              1             0             0          0            1
# 29  Intel              1             0             0          0            1
# 30    Amd              1             0             0          1            0
# 31  Intel              0             0             1          0            1
# 32  Intel              1             0             0          0            1
# 33    Amd              1             0             0          1            0
# 34  Intel              0             0             1          0            1
# 35  Intel              0             0             1          0            1
# 36  Intel              0             0             1          0            1
# 37    Amd              1             0             0          1            0
# 38  Intel              0             0             1          0            1
# 39  Intel              0             0             1          0            1
# 40  Intel              1             0             0          0            1
# 41  Intel              1             0             0          0            1
# 42  Intel              0             0             1          0            1
# 43    Amd              1             0             0          1            0
# 44    Amd              0             0             1          1            0
# 45  Intel              1             0             0          0            1
# 46    Amd              1             0             0          1            0
# 47  Intel              0             0             1          0            1
# 48  Intel              0             0             1          0            1
# 49    Amd              0             0             1          1            0
# 50  Intel              0             0             1          0            1
# 51  Intel              0             0             1          0            1
# 52  Intel              1             0             0          0            1
# 53  Intel              1             0             0          0            1
# 54  Intel              0             0             1          0            1
# 55  Intel              0             0             1          0            1
# 56    Amd              1             0             0          1            0
# 57    Amd              0             0             1          1            0
# 58    Amd              0             0             1          1            0
# 59  Intel              1             0             0          0            1

# %% [markdown]
# Now that our class has been OneHot encoded we can drop our old collumns

# %%
df.drop(['Class'],axis=1,inplace=True)
df.drop(['brand'],axis=1,inplace=True)
df.head()
# Out:
#                             name        price  Socket  Clockspeed  \
# 0  Ryzen Threadripper PRO 3995WX          NaN  sTRX4          2.7
# 1       Ryzen Threadripper 3990X  3849.989990  sTRX4          2.9
# 2                      EPYC 7702  6229.000000    SP3          2.0
# 3                     EPYC 7702P  4088.000000    SP3          2.0
# 4                      EPYC 7742  7549.350098    SP3          2.3
#
#    Turbo Speed  Threads  Cores Typical TDP  mt_score  st_score  class_Desktop  \
# 0          4.2      128     64         280     88673      2676              1
# 1          4.3      128     64         280     80508      2545              1
# 2          3.4      128     64         200     71859      2096              0
# 3          3.4      128     64         200     68213      2210              0
# 4          3.4      128     64         225     67185      2376              0
#
#    class_Laptop  class_Server  brand_Amd  brand_Intel
# 0             0             0          1            0
# 1             0             0          1            0
# 2             0             1          1            0
# 3             0             1          1            0
# 4             0             1          1            0

# %% [markdown]
# Saving the encoded data

# %%
du.save_df(df, 'cpu_data_encoded.csv')

# %% [markdown]
# Verify project structure

# %%
# !tree ../
# Out:
# ../
# ├── LICENSE
# ├── README.md
# ├── data
# │   ├── cpu_data.csv
# │   ├── cpu_data_cleaned.csv
# │   └── cpu_data_encoded.csv
# ├── models
# ├── notebooks
# │   ├── 0_setup_project_folders.ipynb
# │   ├── 1_Retrieving_data.ipynb
# │   ├── 2_Cleaning_data.ipynb
# │   ├── 3_Simple_Graphs.ipynb
# │   └── __pycache__
# │       └── datautil.cpython-37.pyc
# ├── report
# │   ├── interim.md
# │   ├── proposal.md
# │   └── report.md
# └── src
#     ├── __pycache__
#     │   └── datautil.cpython-37.pyc
#     └── datautil.py
#
# 7 directories, 15 files
